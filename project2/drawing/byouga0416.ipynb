# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sys
sys.path.append('..')

import sourse_new

# %%
sourse_new.dt
# Out:
# 7.1282897372711e-10

# %%
(1.75*0.001)/(sourse_new.dt*500)
# Out:
# 4910.013662463577

# %%
5900*0.9
# Out:
# 5310.0

# %%
sourse_new.select_pitch_and_image_exp(125, sourse_new.depth_125)
# Out:
# importing : C:\Users\manat\project2\experience_new\0_0\scope_5b1_0.csv
# importing : C:\Users\manat\project2\experience_new\0_0\scope_5b1_1.csv
# importing : C:\Users\manat\project2\experience_new\0_0\scope_5b1_2.csv
# importing : C:\Users\manat\project2\experience_new\0_0\scope_5b1_3.csv
# importing : C:\Users\manat\project2\experience_new\0_0\scope_5b1_4.csv
# importing : C:\Users\manat\project2\experience_new\0_0\scope_5b1_5.csv
# importing : C:\Users\manat\project2\experience_new\0_0\scope_5b1_6.csv
# importing : C:\Users\manat\project2\experience_new\0_0\scope_5b1_7.csv
# importing : C:\Users\manat\project2\experience_new\0_0\scope_5b1_8.csv
# importing : C:\Users\manat\project2\experience_new\0_0\scope_5b1_9.csv
# importing : C:\Users\manat\project2\experience_new\125_2\scope_5b3_10.csv
# importing : C:\Users\manat\project2\experience_new\125_2\scope_5b3_11.csv
# importing : C:\Users\manat\project2\experience_new\125_2\scope_5b3_12.csv
# ...

# %%
sourse_new.select_pitch_and_image(125, sourse_new.depth_125)

# %%
sourse_new.select_pitch_and_image_exp(200, sourse_new.depth_200)
# Out:
# importing : C:\Users\manat\project2\experience_new\0_0\scope_5b1_0.csv
# importing : C:\Users\manat\project2\experience_new\0_0\scope_5b1_1.csv
# importing : C:\Users\manat\project2\experience_new\0_0\scope_5b1_2.csv
# importing : C:\Users\manat\project2\experience_new\0_0\scope_5b1_3.csv
# importing : C:\Users\manat\project2\experience_new\0_0\scope_5b1_4.csv
# importing : C:\Users\manat\project2\experience_new\0_0\scope_5b1_5.csv
# importing : C:\Users\manat\project2\experience_new\0_0\scope_5b1_6.csv
# importing : C:\Users\manat\project2\experience_new\0_0\scope_5b1_7.csv
# importing : C:\Users\manat\project2\experience_new\0_0\scope_5b1_8.csv
# importing : C:\Users\manat\project2\experience_new\0_0\scope_5b1_9.csv
# importing : C:\Users\manat\project2\experience_new\200_2\scope_5b3_40.csv
# importing : C:\Users\manat\project2\experience_new\200_2\scope_5b3_41.csv
# importing : C:\Users\manat\project2\experience_new\200_2\scope_5b3_42.csv
# ...

# %%
plt.plot(sourse_new.kiritori2(sourse_new.import_data(125, 20)[0], sourse_new.left, sourse_new.right))
# Out:
# importing : C:\Users\manat\project2\experience_new\125_20\scope_5b1_50.csv
# importing : C:\Users\manat\project2\experience_new\125_20\scope_5b1_51.csv
# importing : C:\Users\manat\project2\experience_new\125_20\scope_5b1_52.csv
# importing : C:\Users\manat\project2\experience_new\125_20\scope_5b1_53.csv
# importing : C:\Users\manat\project2\experience_new\125_20\scope_5b1_54.csv
# importing : C:\Users\manat\project2\experience_new\125_20\scope_5b1_55.csv
# importing : C:\Users\manat\project2\experience_new\125_20\scope_5b1_56.csv
# importing : C:\Users\manat\project2\experience_new\125_20\scope_5b1_57.csv
# importing : C:\Users\manat\project2\experience_new\125_20\scope_5b1_58.csv
# importing : C:\Users\manat\project2\experience_new\125_20\scope_5b1_59.csv

# %%
sourse_new.x_length/sourse_new.cl/sourse_new.dt
# Out:
# 4896.529995823572

# %%
plt.plot(sourse_new.kiritori2(sourse_new.interpolate_sim_one(np.loadtxt(r"C:\Users\manat\project2\data_all\cupy_pitch200_depth20.csv")[8000:]),sourse_new.left, sourse_new.right))

# %%
plt.plot(np.loadtxt(r"C:\Users\manat\project2\data_all\cupy_pitch200_depth20.csv")[10300:11100])

# %%
sourse_new.select_pitch_and_image_exp(200, sourse_new.depth_200)
# Out:
# importing : C:\Users\manat\project2\experience_new\0_0\scope_5b1_0.csv
# importing : C:\Users\manat\project2\experience_new\0_0\scope_5b1_1.csv
# importing : C:\Users\manat\project2\experience_new\0_0\scope_5b1_2.csv
# importing : C:\Users\manat\project2\experience_new\0_0\scope_5b1_3.csv
# importing : C:\Users\manat\project2\experience_new\0_0\scope_5b1_4.csv
# importing : C:\Users\manat\project2\experience_new\0_0\scope_5b1_5.csv
# importing : C:\Users\manat\project2\experience_new\0_0\scope_5b1_6.csv
# importing : C:\Users\manat\project2\experience_new\0_0\scope_5b1_7.csv
# importing : C:\Users\manat\project2\experience_new\0_0\scope_5b1_8.csv
# importing : C:\Users\manat\project2\experience_new\0_0\scope_5b1_9.csv
# importing : C:\Users\manat\project2\experience_new\200_2\scope_5b3_40.csv
# importing : C:\Users\manat\project2\experience_new\200_2\scope_5b3_41.csv
# importing : C:\Users\manat\project2\experience_new\200_2\scope_5b3_42.csv
# ...

# %%
sourse_new.select_pitch_and_image_wavy(125, sourse_new.depth_125)
sourse_new.select_pitch_and_image_exp_wavy(125, sourse_new.depth_125)
# Out:
# importing : C:\Users\manat\project2\experience_new\0_0\scope_5b1_0.csv
# importing : C:\Users\manat\project2\experience_new\0_0\scope_5b1_1.csv
# importing : C:\Users\manat\project2\experience_new\0_0\scope_5b1_2.csv
# importing : C:\Users\manat\project2\experience_new\0_0\scope_5b1_3.csv
# importing : C:\Users\manat\project2\experience_new\0_0\scope_5b1_4.csv
# importing : C:\Users\manat\project2\experience_new\0_0\scope_5b1_5.csv
# importing : C:\Users\manat\project2\experience_new\0_0\scope_5b1_6.csv
# importing : C:\Users\manat\project2\experience_new\0_0\scope_5b1_7.csv
# importing : C:\Users\manat\project2\experience_new\0_0\scope_5b1_8.csv
# importing : C:\Users\manat\project2\experience_new\0_0\scope_5b1_9.csv
# importing : C:\Users\manat\project2\experience_new\125_2\scope_5b3_10.csv
# importing : C:\Users\manat\project2\experience_new\125_2\scope_5b3_11.csv
# importing : C:\Users\manat\project2\experience_new\125_2\scope_5b3_12.csv
# ...

# %%
yf, K_wave = sourse_new.make_fftdata_wavy(sourse_new.kiritori2(np.loadtxt(r"C:\Users\manat\project2\data_all\cupy_pitch200_depth20.csv")[8000:], sourse_new.left, sourse_new.right), sourse_new.exp_dt)
# Out:
# cut_data.shape: (4096,)

# %%
plt.plot(K_wave, yf)
plt.xlim(0, 2000)
# Out:
# (0.0, 2000.0)
