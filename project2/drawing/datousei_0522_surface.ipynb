# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sys
sys.path.append('..')
import os
import sourse_new

# %% [markdown]
# 05/22 表面波とプローブの取得波形の時間軸合わせて描画したらええんちゃうの精神

# %%
filename = f"C:\\Users\\manat\\project2\\surface_wave_2d\\T1\\T1_series_middle_morerange.npy"
filename2 = f"C:\\Users\\manat\\project2\\surface_wave_2d\\T3\\T3_series_middle_morerange.npy"
data_kabe_T1 = np.load(filename)
data_yuka_T3 = np.load(filename2)

z1 = 49
z2 = 224
x1 = 30
x2 = 40

plt.imshow(-data_kabe_T1[x1:x2, z1, 1214-sourse_new.left:1214+sourse_new.right], extent=(0, sourse_new.right+sourse_new.left, 0, 10),interpolation='nearest', cmap="jet", aspect='auto')

# %%
plt.imshow(-data_yuka_T3[x2-2, z1:z2, 1214-sourse_new.left:1214+sourse_new.right], interpolation='nearest', cmap="jet", aspect='auto')

# %%
filename = f"C:\\Users\\manat\\project2\\surface_wave_2d\\T1\\T1_series_middle_moremorerange_125_moredepth.npy"
filename2 = f"C:\\Users\\manat\\project2\\surface_wave_2d\\T3\\T3_series_middle_moremorerange_125_moredepth.npy"
data_kabe_T1 = np.load(filename)
data_yuka_T3 = np.load(filename2)

z1 = 201
x1 = 40
x2 = 69

plt.imshow(-data_kabe_T1[x1:x2, z1, 1214-sourse_new.left:1214+sourse_new.right], interpolation='nearest', cmap="jet", aspect='auto')

# %%
plt.imshow(-data_yuka_T3[x2, z1:z1+100, 1214-sourse_new.left:1214+sourse_new.right], interpolation='nearest', cmap="jet", aspect='auto')

# %%
filename2 = f"C:\\Users\\manat\\project2\\surface_wave_2d\\T1\\T1_series_middle_moremorerange_moredepth.npy"
data_kabe_T1_2 = np.load(filename2)

z1_2 = 49
x1_2 = 40
x2_2 = 69

plt.imshow(data_kabe_T1_2[x1_2:x2_2, z1_2, 1214-sourse_new.left:1214+sourse_new.right], interpolation='nearest', cmap="jet", aspect='auto')

# %%
filename2 = f"C:\\Users\\manat\\project2\\surface_wave_2d\\T1\\T1_series_middle_morerange.npy"
data_kabe_T1_2 = np.load(filename2)

z1_2 = 49
x1_2 = 25
x2_2 = 40

plt.imshow(data_kabe_T1_2[x1_2:x2_2, z1_2, 1214-sourse_new.left:1214+sourse_new.right], interpolation='nearest', cmap="jet", aspect='auto')
