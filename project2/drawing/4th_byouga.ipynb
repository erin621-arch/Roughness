# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sys
sys.path.append('..')
import sourse
import os
import sourse_new
import matplotlib.patches as patches

# %%
wave150_3 = np.loadtxt(r"C:\Users\manat\project2\tmp_output\cupy_4th_boundary_pitch150_depth3.csv")
plt.plot(wave150_3)
